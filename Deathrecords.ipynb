# %%
import pandas as pd
import numpy as np
import os
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score

# %%
os.chdir('/Users/Sam/ds/metis/metisgh/sf16_ds4/local/Project3/DeathRecords')

# %%
df = pd.read_csv('DeathRecords.csv')

# %%
df
# Out:
#               Id  ResidentStatus  Education1989Revision  \
# 0              1               1                      0
# 1              2               1                      0
# 2              3               1                      0
# 3              4               1                      0
# 4              5               1                      0
# 5              6               1                      0
# 6              7               1                      0
# 7              8               1                      0
# 8              9               1                      0
# 9             10               1                      0
# 10            11               1                      0
# 11            12               1                      0
# 12            13               1                      0
# 13            14               1                      0
# 14            15               1                      0
# 15            16               1                      0
# ...

# %%
X = df[['ResidentStatus', 'Education1989Revision']]
X
y = df['CauseRecode39']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
model = KNeighborsClassifier()
model.fit(X,y)
model.score(X,y)

# %%
model2 = LogisticRegression()
modelfit2 = model2.fit(X_train, y_train)
y_pred = modelfit2.predict(X_test)
accuracy_score(y_test, y_pred)
# Out:
# 0.19198152408557906
